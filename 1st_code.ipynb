# %%
1
# Out:
# 1

# %%
1+2
# Out:
# 3

# %%
10+5-3
# Out:
# 12

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[1,4,6,9])

# %%
plt.plot([1,2,3,4],[1,8,27,64])

# %%
9
# Out:
# 9

# %%
_+3
# Out:
# 12
